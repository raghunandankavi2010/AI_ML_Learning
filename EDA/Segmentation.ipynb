# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("EDA_nas.csv")

# %%
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
grouped_watch_tv = df.groupby(['Watch.TV']).mean()
grouped_watch_tv
# Out:
# C:\Users\raghu\AppData\Local\Temp\ipykernel_13192\1194494096.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_watch_tv = df.groupby(['Watch.TV']).mean()
#                      STUID  District  Category  Same.language    Maths..  \
# Watch.TV
# Every day     2.608321e+10  8.185168  2.794070       1.092262  31.742637
# Never         2.609323e+10  9.195402  2.842949       1.122024  29.817151
# Once a month  2.608184e+10  8.058252  2.631206       1.237458  32.519456
# Once a week   2.608564e+10  8.435429  2.786686       1.114325  31.408179
#
#               Reading..  Science..   Social..
# Watch.TV
# Every day     55.292724  36.357915  40.416605
# Never         55.225989  35.638589  39.013252
# Once a month  53.697582  36.786127  40.697143
# ...

# %%
# What is the impact of the father’s education on the student’s Maths marks?
table = pd.pivot_table(df, values='Maths..',
                       columns=['Father.edu'], aggfunc=np.mean)

# %%
table
# Out:
# Father.edu  Degree & above  Illiterate    Primary  Secondary  Sr secondary
# Maths..          34.879193   29.126754  32.561137  32.230393     32.493415

# %%
# What is the impact of 'Play.Games' on Reading marks?
table2 = pd.pivot_table(df, values='Reading..',
                       columns=['Play.games'], aggfunc=np.mean)

# %%
table2
# Out:
# Play.games  Every day      Never  Once a month  Once a week
# Reading..   54.780136  49.107484     51.951193    59.627034

# %%
table3 =pd.pivot_table(df, values='Maths..',
                       columns=['Father.occupation'], aggfunc=np.mean)

# %%
table3
# Out:
# Father.occupation  Business      Clerk     Farmer   Labourer  Professional  \
# Maths..            32.86593  33.518826  31.817781  30.391537       33.6148
#
# Father.occupation  Skilled Worker  Teacher/Lecturer  Unemployed
# Maths..                 32.323519         34.958667   29.893993

# %%
df['Solve.Maths']
# Out:
# 0          Agree
# 1          Agree
# 2          Agree
# 3       Disagree
# 4        Neither
#           ...
# 8796       Agree
# 8797       Agree
# 8798       Agree
# 8799       Agree
# 8800       Agree
# Name: Solve.Maths, Length: 8801, dtype: object

# %%
table4 = table3 =pd.pivot_table(df, values='Maths..',
                       columns=['Solve.Maths'], aggfunc=np.mean)

# %%
table4
# Out:
# Solve.Maths     Agree   Disagree    Neither
# Maths..      32.80092  30.841321  29.384388
